# %% [markdown]
# ## reading of file done

# %%
import pandas as pd

# %%
housing=pd.read_csv('data2.csv')

# %%
housing
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458    NaN  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %%
housing.head(
)
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458    NaN  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %%
# %matplotlib inline

# %%
import matplotlib as plt

# %%
housing.hist(bins=50,figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'crim'}>, <Axes: title={'center': 'zn'}>,
#         <Axes: title={'center': 'indus'}>,
#         <Axes: title={'center': 'chas'}>],
#        [<Axes: title={'center': 'nox'}>, <Axes: title={'center': 'rm'}>,
#         <Axes: title={'center': 'age'}>, <Axes: title={'center': 'dis'}>],
#        [<Axes: title={'center': 'rad'}>, <Axes: title={'center': 'tax'}>,
#         <Axes: title={'center': 'ptratio'}>,
#         <Axes: title={'center': 'b'}>],
#        [<Axes: title={'center': 'lstat'}>,
#         <Axes: title={'center': 'medv'}>, <Axes: >, <Axes: >]],
#       dtype=object)

# %%
from pandas.plotting import scatter_matrix
attribute=["medv","rm","lstat"]
scatter_matrix(housing[attribute],figsize=(20,15))
# Out:
# array([[<Axes: xlabel='medv', ylabel='medv'>,
#         <Axes: xlabel='rm', ylabel='medv'>,
#         <Axes: xlabel='lstat', ylabel='medv'>],
#        [<Axes: xlabel='medv', ylabel='rm'>,
#         <Axes: xlabel='rm', ylabel='rm'>,
#         <Axes: xlabel='lstat', ylabel='rm'>],
#        [<Axes: xlabel='medv', ylabel='lstat'>,
#         <Axes: xlabel='rm', ylabel='lstat'>,
#         <Axes: xlabel='lstat', ylabel='lstat'>]], dtype=object)

# %%
scatter_matrix
# Out:
# <function pandas.plotting._misc.scatter_matrix(frame: 'DataFrame', alpha: 'float' = 0.5, figsize: 'tuple[float, float] | None' = None, ax: 'Axes | None' = None, grid: 'bool' = False, diagonal: 'str' = 'hist', marker: 'str' = '.', density_kwds=None, hist_kwds=None, range_padding: 'float' = 0.05, **kwargs) -> 'np.ndarray'>

# %% [markdown]
# ## correlation of data done

# %%
corr_matrix=housing.corr()
corr_matrix['medv'].sort_values(ascending=False)
# Out:
# medv       1.000000
# rm         0.693571
# zn         0.360445
# b          0.333461
# dis        0.249929
# chas       0.175260
# age       -0.376955
# rad       -0.381626
# crim      -0.388305
# nox       -0.427321
# tax       -0.468536
# indus     -0.483725
# ptratio   -0.507787
# lstat     -0.737663
# Name: medv, dtype: float64

# %%
housing=strat_train_set.drop(["medv"],axis=1)
housing_labels=strat_train_set["medv"].copy()

# %%
housing_labels.shape
# Out:
# (404,)

# %% [markdown]
# ## train test done

# %%
from sklearn.model_selection import train_test_split
train_set,test_set=train_test_split(housing,test_size=0.2,random_state=42)
print(f"rows in train_set is: {len(train_set)}\nrows in test_set is: {len(test_set)}")
# Out:
# rows in train_set is: 404
# rows in test_set is: 102

# %%
housing['chas'].value_counts()
# Out:
# chas
# 0    471
# 1     35
# Name: count, dtype: int64

# %%
from sklearn.model_selection import StratifiedShuffleSplit
split=StratifiedShuffleSplit(n_splits=1,test_size=0.2,random_state=42)
for train_index,test_index in split.split(housing,housing['chas']):
    strat_test_set=housing.loc[test_index]
    strat_train_set=housing.loc[train_index]

# %%
housing.plot(kind='scatter',x="lstat",y="medv",alpha=0.8)
# Out:
# <Axes: xlabel='lstat', ylabel='medv'>

# %%
from sklearn.impute import SimpleImputer
impute=SimpleImputer(strategy="median")

# %%
impute.fit(housing)
# Out:
# SimpleImputer(strategy='median')

# %%
impute.statistics_
# Out:
# array([2.56510e-01, 0.00000e+00, 9.69000e+00, 0.00000e+00, 5.38000e-01,
#        6.20900e+00, 7.75000e+01, 3.20745e+00, 5.00000e+00, 3.30000e+02,
#        1.90500e+01, 3.91440e+02, 1.13600e+01, 2.12000e+01])

# %%
x=impute.transform(housing)
print(x)
# Out:
# [[6.3200e-03 1.8000e+01 2.3100e+00 ... 3.9690e+02 4.9800e+00 2.4000e+01]
#  [2.7310e-02 0.0000e+00 7.0700e+00 ... 3.9690e+02 9.1400e+00 2.1600e+01]
#  [2.7290e-02 0.0000e+00 7.0700e+00 ... 3.9283e+02 4.0300e+00 3.4700e+01]
#  ...
#  [6.0760e-02 0.0000e+00 1.1930e+01 ... 3.9690e+02 5.6400e+00 2.3900e+01]
#  [1.0959e-01 0.0000e+00 1.1930e+01 ... 3.9345e+02 6.4800e+00 2.2000e+01]
#  [4.7410e-02 0.0000e+00 1.1930e+01 ... 3.9690e+02 7.8800e+00 1.1900e+01]]

# %%
housing_tr=pd.DataFrame(x,columns=housing.columns)

# %%
housing_tr
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad    tax
# 0    0.00632  18.0   2.31   0.0  0.538  6.575  65.2  4.0900  1.0  296.0  \
# 1    0.02731   0.0   7.07   0.0  0.469  6.421  78.9  4.9671  2.0  242.0
# 2    0.02729   0.0   7.07   0.0  0.469  7.185  61.1  4.9671  2.0  242.0
# 3    0.03237   0.0   2.18   0.0  0.458  6.998  45.8  6.0622  3.0  222.0
# 4    0.06905   0.0   2.18   0.0  0.458  6.209  54.2  6.0622  3.0  222.0
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...    ...
# 501  0.06263   0.0  11.93   0.0  0.573  6.593  69.1  2.4786  1.0  273.0
# 502  0.04527   0.0  11.93   0.0  0.573  6.120  76.7  2.2875  1.0  273.0
# 503  0.06076   0.0  11.93   0.0  0.573  6.976  91.0  2.1675  1.0  273.0
# 504  0.10959   0.0  11.93   0.0  0.573  6.794  89.3  2.3889  1.0  273.0
# 505  0.04741   0.0  11.93   0.0  0.573  6.030  80.8  2.5050  1.0  273.0
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# ...

# %%
housing_tr.to_csv('raunak.csv')

# %% [markdown]
# ## feature scaling
# primarly ther are two type
# 1.min-maax scaling(normalization)
# (value-min)/(max-min)=iska value hameza 0-1 ke beech me lyi karega
# class is minmaxscaler
# 2.standardization
# (value-min)/standarddaviation
# sklearn provide class called standardscaler

# %% [markdown]
# pipeline ka matlab series of step krenge

# %%
from sklearn.pipeline import Pipeline
from sklearn.preprocessing import StandardScaler
my_pipeline=Pipeline([
      ('imputer',SimpleImputer(strategy='median')),
      ('std_scaler',StandardScaler()),
])

# %%
housing_num_tr=my_pipeline.fit_transform(housing)

# %%
housing_num_tr
# Out:
# array([[-0.43942006,  3.12628155, -1.12165014, ..., -0.97491834,
#          0.41164221, -0.86091034],
#        [-0.44352175,  3.12628155, -1.35893781, ..., -0.69277865,
#          0.39131918, -0.94116739],
#        [ 0.15682292, -0.4898311 ,  0.98336806, ...,  0.81196637,
#          0.44624347,  0.81480158],
#        ...,
#        [-0.43525657, -0.4898311 , -1.23083158, ..., -0.22254583,
#          0.41831233, -1.27603303],
#        [ 0.14210728, -0.4898311 ,  0.98336806, ...,  0.81196637,
#         -3.15239177,  0.73869575],
#        [-0.43974024, -0.4898311 ,  0.37049623, ..., -0.97491834,
#          0.41070422,  0.09940681]])

# %% [markdown]
# ## selecting a desired model for dragon real estates

# %%
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
#model=DecisionTreeRegressor()
model=RandomForestRegressor()
model.fit(housing_num_tr,housing_labels)
# Out:
# RandomForestRegressor()

# %%
some_data=housing.iloc[:5]

# %%
some_labels=housing_labels.iloc[:]

# %%
prepared_data=my_pipeline.transform(some_data)

# %%
model.predict(prepared_data)
# Out:
# array([21.9, 24.5, 16.7, 23.1, 23. ])

# %%
some_labels.head()
# Out:
# 254    21.9
# 348    24.5
# 476    16.7
# 321    23.1
# 326    23.0
# Name: medv, dtype: float64

# %% [markdown]
#  ## evaluating model

# %%
from sklearn.metrics import mean_squared_error
import numpy as np
housing_predictions=model.predict(housing_num_tr)
mse=mean_squared_error(housing_labels,housing_predictions)
rmse=np.sqrt(mse)

# %% [markdown]
# ## overfitting issue

# %%
rmse
# Out:
# 1.2115292939908706

# %% [markdown]
# ## using better evaluation technique-cross validation

# %%
from sklearn.model_selection import cross_val_score

# %%
score=cross_val_score(model,housing_num_tr,housing_labels,scoring="neg_mean_squared_error",cv=10)

# %%
rmse_score=np.sqrt(-score)

# %%
rmse_score
# Out:
# array([2.83818823, 2.76175024, 4.56444346, 2.63592218, 3.32372647,
#        2.62099015, 4.276317  , 3.72873285, 3.33413052, 3.1092917 ])

# %% [markdown]
# ## making function

# %%
def print_score(score):
    print("score:",score)
    print("mean:",score.mean())
    print("standard deviation:",score.std())

# %%
print_score(rmse_score)
# Out:
# score: [2.83818823 2.76175024 4.56444346 2.63592218 3.32372647 2.62099015
#  4.276317   3.72873285 3.33413052 3.1092917 ]
# mean: 3.319349280748549
# standard deviation: 0.6461589727967875

# %% [markdown]
# ## saving the model

# %%
from joblib import dump,load
dump(model,'dragon.joblib')
# Out:
# ['dragon.joblib']

# %% [markdown]
# ## testing the model on test data

# %%
x_test=strat_test_set.drop("medv",axis=1)
y_test=strat_test_set["medv"].copy()
x_test_prepared=my_pipeline.transform(x_test)
final_prediction=model.predict(x_test_prepared)
final_mse=mean_squared_error(y_test,final_prediction)
final_rmse=np.sqrt(final_mse)
print(final_prediction,list(y_test))
# Out:
# [24.467 11.332 25.344 22.101 18.77  15.247 19.811 14.032 31.559 41.264
#  19.431 12.109 24.096 27.131 19.712 11.566 31.761 14.148 23.778 18.539
#  20.084 18.134 17.698 22.017 17.899 31.157 16.036 32.689  9.151 33.474
#  23.927 21.455 23.083 10.685 21.488 11.271 43.504 24.844 24.249 42.666
#  24.016 29.598 20.855 21.411 18.571 33.704 44.532 19.897 20.153 22.17
#  21.255 14.641 21.648 14.707 24.669 33.036 41.713 29.008 19.289 20.628
#  46.697  9.722 19.039 27.538 14.54  32.247 19.877 17.862 19.231 33.047
#  25.958 22.928 20.567 22.42  34.412 12.92  16.007 20.31  20.898 21.376
#  22.523 21.046 14.505 22.648 21.018 20.905 14.399 21.143 21.567 23.283
#  18.795 27.626  6.979 26.477 19.242 29.55  19.94  30.638 14.59  27.594
# ...

# %%
final_rmse
# Out:
# 2.8690418414926064

# %%
prepared_data[0]
# Out:
# array([-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
#        -0.24682016, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
#        -0.97491834,  0.41164221, -0.86091034])

# %%
import numpy as np
from joblib import dump,load
model=load('dragon.joblib')

# %%
input=np.array([[-0.43942006,  3.12628155, -1.12165014, -0.27288841, -1.42262747,
       -0.24682016, -1.31238772,  2.61111401, -1.0016859 , -0.5778192 ,
       -0.97491834,  0.41164221, -0.86091034]])

# %%
model.predict(input)
# Out:
# array([22.417])
